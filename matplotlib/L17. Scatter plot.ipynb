# %% [markdown]
# # Scatter plot
# - 두 변수의 상관관계를 직교좌표계의 평면에 점으로 표현하는 그래프
#
# ![image](https://user-images.githubusercontent.com/70187490/125892577-68625a1b-f5f0-4d4c-82ac-4c9d05bc5aba.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)

plt.scatter(x, y);

# %% [markdown]
# ## 색상과 크기 지정하기
#
# ![image](https://user-images.githubusercontent.com/70187490/125892743-e84096c5-6cad-432d-9735-be49c1f3a16c.png)

# %%
np.random.seed(0)

n = 50
x = np.random.rand(n) 
y = np.random.rand(n)
area = (30 * np.random.rand(n))**2
colors = np.random.rand(n)

plt.scatter(x, y, s=area, c=colors);
# 마커의 색상은 데이터의 길이와 같은 크기의 숫자 시퀀스 또는 rgb, 그리고 Hex code 색상을 입력해서 지정

# %%
plt.plot(1,1,'o',markersize=20,c='#FF5733')
plt.scatter(2,1, s=20**2, c='#33FFCE')

plt.text(0.5, 1.05, 'plot(markersize=20)', fontdict={'size':14})
plt.text(1.6, 1.05, 'scatter(s=20**2)', fontdict={'size':14})
plt.axis([0.4, 2.6, 0.8, 1.2]);

# %% [markdown]
# ## 투명도와 컬러맵 설정하기
#
# ![image](https://user-images.githubusercontent.com/70187490/125893706-0568ec72-7b3c-4b59-82fe-e68f2f3498a2.png)

# %%
np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)
area = (30 * np.random.rand(n))**2
colors = np.random.rand(n)

plt.scatter(x, y, s=area, c=colors, alpha=0.5, cmap='Spectral')
plt.colorbar();

# %%
plt.plot(np.random.randn(50), 'o');

# %%
plt.figure(figsize=(8,4))
markers = ['.',',','o','v','^','<','>','1','2','3','4','p','s','*','h','H','d','D','+','|','_']
for m in markers:
    plt.plot(np.random.randn(5), np.random.randn(5), m, label="'{0}'".format(m))
    
plt.legend(loc='center right', ncol=2)
plt.xlim(0, 1.5);

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, 'o');

# %%
plt.scatter(x, y, marker='o');

# %%
plt.figure(figsize=(10, 6))

for i in range(9):
    x = np.arange(1000)
    y = np.random.randn(1000).cumsum()
    plt.scatter(x, y, alpha=0.2, cmap='viridis')

# %%
x = np.random.randn(100)
y = np.random.randn(100)
colors = np.random.rand(100)
sizes = 1000* np.random.rand(100)

plt.figure(figsize=(10, 6))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='viridis')
plt.colorbar();

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='plasma')
plt.colorbar();

# %%
x = np.random.random(200)
y1 = np.random.randn(len(x))
y2 = 1.1 * np.exp(x)

plt.figure(figsize=(10, 6))
ax1 = plt.plot( )
plt.scatter(x, y1, color='indigo', alpha=0.3, label='no correlation')
plt.scatter(x, y2, color='blue', alpha=0.2, label='correlation')
plt.grid(True)
plt.legend();
